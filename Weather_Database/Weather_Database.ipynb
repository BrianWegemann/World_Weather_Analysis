# %%
import random
import pandas as pd
from citipy import citipy
import matplotlib.pyplot as plt
# Import the NumPy module.
import numpy as np
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=00b87dbdab3df67364d83ea94d272af9

# %%
import time
from datetime import datetime

# %%
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

    
for i, city in enumerate(cities):

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 1 | blackwater
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | lapithos
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | leningradskiy
# Processing Record 10 of Set 1 | meadow lake
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | mehamn
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | ashland
# Processing Record 15 of Set 1 | ponoka
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | haines junction
# Processing Record 18 of Set 1 | dubenskiy
# City not found. Skipping...
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 1 | sistranda
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | honolulu
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | tukrah
# Processing Record 29 of Set 1 | dunedin
# Processing Record 30 of Set 1 | saint-georges
# Processing Record 31 of Set 1 | lorengau
# Processing Record 32 of Set 1 | srednekolymsk
# Processing Record 33 of Set 1 | lozuvatka
# Processing Record 34 of Set 1 | sorland
# Processing Record 35 of Set 1 | antanifotsy
# Processing Record 36 of Set 1 | kailua
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | north bend
# Processing Record 40 of Set 1 | pokrovsk
# Processing Record 41 of Set 1 | koboldo
# City not found. Skipping...
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | homer
# Processing Record 44 of Set 1 | mecca
# Processing Record 45 of Set 1 | upernavik
# Processing Record 46 of Set 1 | viru
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | severo-kurilsk
# Processing Record 49 of Set 1 | olafsvik
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | waipawa
# Processing Record 4 of Set 2 | vostok
# Processing Record 5 of Set 2 | zhigansk
# Processing Record 6 of Set 2 | calabar
# Processing Record 7 of Set 2 | matamoros
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | lambarene
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | koslan
# Processing Record 12 of Set 2 | honiara
# Processing Record 13 of Set 2 | deputatskiy
# Processing Record 14 of Set 2 | nur
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | salekhard
# Processing Record 17 of Set 2 | rotifunk
# Processing Record 18 of Set 2 | bilibino
# Processing Record 19 of Set 2 | langsa
# Processing Record 20 of Set 2 | eirunepe
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | mount gambier
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | pisco
# Processing Record 26 of Set 2 | nikolskoye
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | college
# Processing Record 30 of Set 2 | dhidhdhoo
# Processing Record 31 of Set 2 | cidreira
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 2 | bethel
# Processing Record 35 of Set 2 | acapulco
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | negara
# Processing Record 38 of Set 2 | meulaboh
# Processing Record 39 of Set 2 | paita
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | honningsvag
# Processing Record 42 of Set 2 | baykit
# Processing Record 43 of Set 2 | lagos
# Processing Record 44 of Set 2 | tecoanapa
# Processing Record 45 of Set 2 | kununurra
# Processing Record 46 of Set 2 | kaili
# Processing Record 47 of Set 2 | san quintin
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | tortoli
# Processing Record 50 of Set 2 | hobart
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 3 | pilar
# Processing Record 4 of Set 3 | zaysan
# Processing Record 5 of Set 3 | ilulissat
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | yerbogachen
# Processing Record 8 of Set 3 | camacupa
# Processing Record 9 of Set 3 | mezen
# Processing Record 10 of Set 3 | kalabo
# Processing Record 11 of Set 3 | bilma
# Processing Record 12 of Set 3 | dalvik
# Processing Record 13 of Set 3 | tiksi
# Processing Record 14 of Set 3 | pemangkat
# Processing Record 15 of Set 3 | bluff
# Processing Record 16 of Set 3 | pekan
# Processing Record 17 of Set 3 | saint pete beach
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | qaanaaq
# Processing Record 20 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 22 of Set 3 | port hardy
# Processing Record 23 of Set 3 | dakar
# Processing Record 24 of Set 3 | nouakchott
# Processing Record 25 of Set 3 | kaitangata
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | santa barbara
# Processing Record 28 of Set 3 | semey
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | salalah
# Processing Record 31 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | lata
# Processing Record 33 of Set 3 | kodiak
# Processing Record 34 of Set 3 | richards bay
# Processing Record 35 of Set 3 | korla
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | zhangjiakou
# Processing Record 38 of Set 3 | belle fourche
# Processing Record 39 of Set 3 | yellowknife
# Processing Record 40 of Set 3 | kyzyl-suu
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | rocha
# Processing Record 43 of Set 3 | codrington
# Processing Record 44 of Set 3 | boyolangu
# Processing Record 45 of Set 3 | panaba
# Processing Record 46 of Set 3 | saint george
# Processing Record 47 of Set 3 | sakakah
# Processing Record 48 of Set 3 | bolshoy kamen
# Processing Record 49 of Set 3 | sosnovo-ozerskoye
# Processing Record 50 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 4 | cuiluan
# Processing Record 2 of Set 4 | harper
# Processing Record 3 of Set 4 | ukiah
# Processing Record 4 of Set 4 | tagab
# Processing Record 5 of Set 4 | rutana
# Processing Record 6 of Set 4 | mayo
# Processing Record 7 of Set 4 | kidal
# Processing Record 8 of Set 4 | tezu
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | karratha
# Processing Record 11 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 4 | bairiki
# Processing Record 13 of Set 4 | kruisfontein
# Processing Record 14 of Set 4 | kerema
# Processing Record 15 of Set 4 | romny
# Processing Record 16 of Set 4 | les escoumins
# Processing Record 17 of Set 4 | oktyabrskiy
# Processing Record 18 of Set 4 | lucea
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | bubaque
# Processing Record 21 of Set 4 | kikwit
# Processing Record 22 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 4 | neijiang
# Processing Record 24 of Set 4 | ancud
# Processing Record 25 of Set 4 | shingu
# Processing Record 26 of Set 4 | daru
# Processing Record 27 of Set 4 | biltine
# Processing Record 28 of Set 4 | avera
# Processing Record 29 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 4 | diamantino
# Processing Record 31 of Set 4 | namatanai
# Processing Record 32 of Set 4 | two hills
# Processing Record 33 of Set 4 | cabatuan
# Processing Record 34 of Set 4 | alice springs
# Processing Record 35 of Set 4 | ostrovnoy
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | saint-leu
# Processing Record 38 of Set 4 | grindavik
# Processing Record 39 of Set 4 | kitale
# Processing Record 40 of Set 4 | chino valley
# Processing Record 41 of Set 4 | kavieng
# Processing Record 42 of Set 4 | ouadda
# Processing Record 43 of Set 4 | takoradi
# Processing Record 44 of Set 4 | gat
# Processing Record 45 of Set 4 | anloga
# Processing Record 46 of Set 4 | talcahuano
# Processing Record 47 of Set 4 | collie
# Processing Record 48 of Set 4 | kabalo
# Processing Record 49 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 4 | necochea
# Processing Record 1 of Set 5 | raga
# Processing Record 2 of Set 5 | vargem grande
# Processing Record 3 of Set 5 | saint anthony
# Processing Record 4 of Set 5 | coihaique
# Processing Record 5 of Set 5 | koronowo
# Processing Record 6 of Set 5 | atambua
# Processing Record 7 of Set 5 | tolstoy-yurt
# Processing Record 8 of Set 5 | maceio
# Processing Record 9 of Set 5 | torbay
# Processing Record 10 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | victoria
# Processing Record 13 of Set 5 | bengkulu
# Processing Record 14 of Set 5 | laguna
# Processing Record 15 of Set 5 | coquimbo
# Processing Record 16 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 5 | mackay
# Processing Record 18 of Set 5 | kadhan
# Processing Record 19 of Set 5 | norman wells
# Processing Record 20 of Set 5 | fallon
# Processing Record 21 of Set 5 | saint-raymond
# Processing Record 22 of Set 5 | plettenberg bay
# Processing Record 23 of Set 5 | krasnoselkup
# Processing Record 24 of Set 5 | sinop
# Processing Record 25 of Set 5 | cayenne
# Processing Record 26 of Set 5 | anadyr
# Processing Record 27 of Set 5 | sinnamary
# Processing Record 28 of Set 5 | abha
# Processing Record 29 of Set 5 | awbari
# Processing Record 30 of Set 5 | barra patuca
# Processing Record 31 of Set 5 | itanhem
# Processing Record 32 of Set 5 | kysyl-syr
# Processing Record 33 of Set 5 | hamilton
# Processing Record 34 of Set 5 | vila velha
# Processing Record 35 of Set 5 | rio negrinho
# Processing Record 36 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 5 | sitka
# Processing Record 38 of Set 5 | nanortalik
# Processing Record 39 of Set 5 | chifeng
# Processing Record 40 of Set 5 | pangnirtung
# Processing Record 41 of Set 5 | iqaluit
# Processing Record 42 of Set 5 | seoul
# Processing Record 43 of Set 5 | labrea
# Processing Record 44 of Set 5 | narsaq
# Processing Record 45 of Set 5 | yeppoon
# Processing Record 46 of Set 5 | isiro
# Processing Record 47 of Set 5 | suao
# City not found. Skipping...
# Processing Record 48 of Set 5 | vestmanna
# Processing Record 49 of Set 5 | esperance
# Processing Record 50 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 6 | nabire
# Processing Record 2 of Set 6 | ipixuna
# Processing Record 3 of Set 6 | butaritari
# Processing Record 4 of Set 6 | sao joao da barra
# Processing Record 5 of Set 6 | newport
# Processing Record 6 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 6 | sivaki
# Processing Record 8 of Set 6 | luderitz
# Processing Record 9 of Set 6 | rambha
# Processing Record 10 of Set 6 | zelenogorskiy
# Processing Record 11 of Set 6 | saint-philippe
# Processing Record 12 of Set 6 | svetlogorsk
# Processing Record 13 of Set 6 | huarmey
# Processing Record 14 of Set 6 | vardo
# Processing Record 15 of Set 6 | klaksvik
# Processing Record 16 of Set 6 | staraya russa
# Processing Record 17 of Set 6 | zima
# Processing Record 18 of Set 6 | mugla
# Processing Record 19 of Set 6 | mbala
# Processing Record 20 of Set 6 | tuatapere
# Processing Record 21 of Set 6 | luganville
# Processing Record 22 of Set 6 | las palmas
# Processing Record 23 of Set 6 | bida
# Processing Record 24 of Set 6 | katha
# City not found. Skipping...
# Processing Record 25 of Set 6 | harsin
# Processing Record 26 of Set 6 | pitimbu
# Processing Record 27 of Set 6 | saint-pierre
# Processing Record 28 of Set 6 | quelimane
# Processing Record 29 of Set 6 | pyaozerskiy
# Processing Record 30 of Set 6 | tuktoyaktuk
# Processing Record 31 of Set 6 | verkhnevilyuysk
# Processing Record 32 of Set 6 | puerto del rosario
# Processing Record 33 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 6 | banjar
# Processing Record 35 of Set 6 | yevpatoriya
# Processing Record 36 of Set 6 | tabou
# Processing Record 37 of Set 6 | egvekinot
# Processing Record 38 of Set 6 | tilichiki
# Processing Record 39 of Set 6 | shetpe
# Processing Record 40 of Set 6 | liverpool
# Processing Record 41 of Set 6 | fort nelson
# Processing Record 42 of Set 6 | banyo
# Processing Record 43 of Set 6 | malim
# Processing Record 44 of Set 6 | isangel
# Processing Record 45 of Set 6 | filingue
# Processing Record 46 of Set 6 | nemuro
# Processing Record 47 of Set 6 | cavalcante
# Processing Record 48 of Set 6 | praia da vitoria
# Processing Record 49 of Set 6 | flinders
# Processing Record 50 of Set 6 | innisfail
# Processing Record 1 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 2 of Set 7 | riachao do jacuipe
# Processing Record 3 of Set 7 | eureka
# Processing Record 4 of Set 7 | jasper
# Processing Record 5 of Set 7 | pangody
# Processing Record 6 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 7 of Set 7 | hanna
# Processing Record 8 of Set 7 | san carlos de bariloche
# Processing Record 9 of Set 7 | te anau
# Processing Record 10 of Set 7 | sungaipenuh
# Processing Record 11 of Set 7 | ambilobe
# Processing Record 12 of Set 7 | sola
# Processing Record 13 of Set 7 | beringovskiy
# Processing Record 14 of Set 7 | bac lieu
# Processing Record 15 of Set 7 | guerrero negro
# Processing Record 16 of Set 7 | mazyr
# Processing Record 17 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 7 | havoysund
# Processing Record 19 of Set 7 | touros
# Processing Record 20 of Set 7 | manyana
# Processing Record 21 of Set 7 | faanui
# Processing Record 22 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 7 | samarai
# Processing Record 24 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 25 of Set 7 | taltal
# Processing Record 26 of Set 7 | thio
# Processing Record 27 of Set 7 | hambantota
# Processing Record 28 of Set 7 | trinidad
# Processing Record 29 of Set 7 | tucupita
# Processing Record 30 of Set 7 | bereda
# Processing Record 31 of Set 7 | mogadishu
# Processing Record 32 of Set 7 | castro
# Processing Record 33 of Set 7 | lompoc
# Processing Record 34 of Set 7 | aquiraz
# Processing Record 35 of Set 7 | talnakh
# Processing Record 36 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 7 | maralal
# Processing Record 38 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 7 | mount isa
# Processing Record 40 of Set 7 | belmonte
# Processing Record 41 of Set 7 | andilamena
# Processing Record 42 of Set 7 | kahului
# Processing Record 43 of Set 7 | culleredo
# Processing Record 44 of Set 7 | vyshhorod
# Processing Record 45 of Set 7 | chapeco
# Processing Record 46 of Set 7 | airai
# Processing Record 47 of Set 7 | compiegne
# Processing Record 48 of Set 7 | porbandar
# Processing Record 49 of Set 7 | nizhniy kuranakh
# Processing Record 50 of Set 7 | burica
# City not found. Skipping...
# Processing Record 1 of Set 8 | nandyal
# Processing Record 2 of Set 8 | petropavlovskoye
# Processing Record 3 of Set 8 | naze
# Processing Record 4 of Set 8 | hualmay
# Processing Record 5 of Set 8 | senno
# Processing Record 6 of Set 8 | constitucion
# Processing Record 7 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 8 | saint-francois
# Processing Record 9 of Set 8 | aksu
# Processing Record 10 of Set 8 | sao filipe
# Processing Record 11 of Set 8 | kawalu
# Processing Record 12 of Set 8 | carlsbad
# Processing Record 13 of Set 8 | bambous virieux
# Processing Record 14 of Set 8 | fairbanks
# Processing Record 15 of Set 8 | smidovich
# Processing Record 16 of Set 8 | erenhot
# Processing Record 17 of Set 8 | yamada
# Processing Record 18 of Set 8 | kachikau
# City not found. Skipping...
# Processing Record 19 of Set 8 | merrill
# Processing Record 20 of Set 8 | aklavik
# Processing Record 21 of Set 8 | cabo san lucas
# Processing Record 22 of Set 8 | mpanda
# Processing Record 23 of Set 8 | desaguadero
# Processing Record 24 of Set 8 | igrim
# Processing Record 25 of Set 8 | hailey
# Processing Record 26 of Set 8 | mairipora
# Processing Record 27 of Set 8 | koutiala
# Processing Record 28 of Set 8 | korhogo
# Processing Record 29 of Set 8 | shieli
# Processing Record 30 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 31 of Set 8 | praxedis guerrero
# Processing Record 32 of Set 8 | almaznyy
# Processing Record 33 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 8 | strezhevoy
# Processing Record 35 of Set 8 | basco
# Processing Record 36 of Set 8 | marrakesh
# Processing Record 37 of Set 8 | itarema
# Processing Record 38 of Set 8 | kolpashevo
# Processing Record 39 of Set 8 | gaborone
# Processing Record 40 of Set 8 | great yarmouth
# Processing Record 41 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 42 of Set 8 | lircay
# Processing Record 43 of Set 8 | provideniya
# Processing Record 44 of Set 8 | cumaral
# Processing Record 45 of Set 8 | san pedro
# Processing Record 46 of Set 8 | cam ranh
# Processing Record 47 of Set 8 | smirnykh
# Processing Record 48 of Set 8 | iquique
# Processing Record 49 of Set 8 | qaqortoq
# Processing Record 50 of Set 8 | cap malheureux
# Processing Record 1 of Set 9 | ercis
# Processing Record 2 of Set 9 | kautokeino
# Processing Record 3 of Set 9 | kloulklubed
# Processing Record 4 of Set 9 | unai
# Processing Record 5 of Set 9 | anchorage
# Processing Record 6 of Set 9 | hovd
# Processing Record 7 of Set 9 | nantucket
# Processing Record 8 of Set 9 | ambon
# Processing Record 9 of Set 9 | westport
# Processing Record 10 of Set 9 | camacha
# Processing Record 11 of Set 9 | balabac
# Processing Record 12 of Set 9 | makat
# Processing Record 13 of Set 9 | longyearbyen
# Processing Record 14 of Set 9 | gushi
# Processing Record 15 of Set 9 | batagay
# Processing Record 16 of Set 9 | bucerias
# Processing Record 17 of Set 9 | raudeberg
# Processing Record 18 of Set 9 | arkadak
# Processing Record 19 of Set 9 | itoman
# Processing Record 20 of Set 9 | arkhangelsk
# Processing Record 21 of Set 9 | hare bay
# Processing Record 22 of Set 9 | lowestoft
# Processing Record 23 of Set 9 | makung
# City not found. Skipping...
# Processing Record 24 of Set 9 | qrendi
# Processing Record 25 of Set 9 | qui nhon
# Processing Record 26 of Set 9 | rio brilhante
# Processing Record 27 of Set 9 | cassia
# Processing Record 28 of Set 9 | praia
# Processing Record 29 of Set 9 | vanimo
# Processing Record 30 of Set 9 | mogzon
# Processing Record 31 of Set 9 | baruun-urt
# Processing Record 32 of Set 9 | warah
# Processing Record 33 of Set 9 | kayerkan
# Processing Record 34 of Set 9 | pemba
# Processing Record 35 of Set 9 | tautira
# Processing Record 36 of Set 9 | pundaguitan
# Processing Record 37 of Set 9 | taitung
# Processing Record 38 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 9 | marsa matruh
# Processing Record 40 of Set 9 | la orilla
# Processing Record 41 of Set 9 | okha
# Processing Record 42 of Set 9 | louis trichardt
# Processing Record 43 of Set 9 | culpeper
# Processing Record 44 of Set 9 | vilcun
# Processing Record 45 of Set 9 | teykovo
# Processing Record 46 of Set 9 | gafanha da encarnacao
# Processing Record 47 of Set 9 | bam
# Processing Record 48 of Set 9 | henties bay
# Processing Record 49 of Set 9 | asuncion
# Processing Record 50 of Set 9 | chickasha
# Processing Record 1 of Set 10 | ayagoz
# Processing Record 2 of Set 10 | bambanglipuro
# Processing Record 3 of Set 10 | ahipara
# Processing Record 4 of Set 10 | west wendover
# Processing Record 5 of Set 10 | vestmannaeyjar
# Processing Record 6 of Set 10 | bulawayo
# Processing Record 7 of Set 10 | sambava
# Processing Record 8 of Set 10 | raposos
# Processing Record 9 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 10 of Set 10 | humen
# Processing Record 11 of Set 10 | megion
# Processing Record 12 of Set 10 | khandbari
# Processing Record 13 of Set 10 | rawson
# Processing Record 14 of Set 10 | mareeba
# Processing Record 15 of Set 10 | los banos
# Processing Record 16 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 10 | quatre cocos
# Processing Record 18 of Set 10 | vila franca do campo
# Processing Record 19 of Set 10 | wembley
# Processing Record 20 of Set 10 | lagoa
# Processing Record 21 of Set 10 | kutum
# Processing Record 22 of Set 10 | tigil
# Processing Record 23 of Set 10 | barzas
# Processing Record 24 of Set 10 | goksun
# Processing Record 25 of Set 10 | carmunnock
# Processing Record 26 of Set 10 | mgandu
# Processing Record 27 of Set 10 | redcar
# Processing Record 28 of Set 10 | hirata
# Processing Record 29 of Set 10 | jiwani
# Processing Record 30 of Set 10 | nyrob
# Processing Record 31 of Set 10 | hervey bay
# Processing Record 32 of Set 10 | pangai
# Processing Record 33 of Set 10 | gondar
# Processing Record 34 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 10 | bandarbeyla
# Processing Record 36 of Set 10 | uvarovka
# Processing Record 37 of Set 10 | sabang
# Processing Record 38 of Set 10 | bonthe
# Processing Record 39 of Set 10 | alugan
# Processing Record 40 of Set 10 | riyadh
# Processing Record 41 of Set 10 | hollins
# Processing Record 42 of Set 10 | rio grande
# Processing Record 43 of Set 10 | kualakapuas
# Processing Record 44 of Set 10 | lavrentiya
# Processing Record 45 of Set 10 | nahrin
# Processing Record 46 of Set 10 | fortuna
# Processing Record 47 of Set 10 | tornio
# Processing Record 48 of Set 10 | aldan
# Processing Record 49 of Set 10 | brownwood
# Processing Record 50 of Set 10 | port lincoln
# Processing Record 1 of Set 11 | faya
# Processing Record 2 of Set 11 | guarapari
# Processing Record 3 of Set 11 | sivas
# Processing Record 4 of Set 11 | nhulunbuy
# Processing Record 5 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 11 | osmena
# Processing Record 7 of Set 11 | havelock
# Processing Record 8 of Set 11 | providencia
# Processing Record 9 of Set 11 | omsukchan
# Processing Record 10 of Set 11 | youkounkoun
# Processing Record 11 of Set 11 | grand gaube
# Processing Record 12 of Set 11 | nadvoitsy
# Processing Record 13 of Set 11 | caohai
# Processing Record 14 of Set 11 | green river
# Processing Record 15 of Set 11 | batagay-alyta
# Processing Record 16 of Set 11 | tessalit
# Processing Record 17 of Set 11 | severo-yeniseyskiy
# Processing Record 18 of Set 11 | kui buri
# Processing Record 19 of Set 11 | cahokia
# Processing Record 20 of Set 11 | wilkie
# Processing Record 21 of Set 11 | beyneu
# Processing Record 22 of Set 11 | lomovka
# Processing Record 23 of Set 11 | pacific grove
# Processing Record 24 of Set 11 | topolobampo
# Processing Record 25 of Set 11 | gladstone
# Processing Record 26 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 11 | fare
# Processing Record 28 of Set 11 | kilindoni
# Processing Record 29 of Set 11 | kasiri
# Processing Record 30 of Set 11 | pimentel
# Processing Record 31 of Set 11 | alofi
# Processing Record 32 of Set 11 | granada
# Processing Record 33 of Set 11 | bollnas
# Processing Record 34 of Set 11 | ndele
# Processing Record 35 of Set 11 | chinchani
# Processing Record 36 of Set 11 | sompeta
# Processing Record 37 of Set 11 | comodoro rivadavia
# Processing Record 38 of Set 11 | bathsheba
# Processing Record 39 of Set 11 | siguiri
# Processing Record 40 of Set 11 | fuerte
# Processing Record 41 of Set 11 | tazovskiy
# Processing Record 42 of Set 11 | banfora
# Processing Record 43 of Set 11 | marsassoum
# Processing Record 44 of Set 11 | we
# City not found. Skipping...
# Processing Record 45 of Set 11 | balikpapan
# Processing Record 46 of Set 11 | cozumel
# Processing Record 47 of Set 11 | san cristobal
# Processing Record 48 of Set 11 | lixourion
# Processing Record 49 of Set 11 | maneadero
# Processing Record 50 of Set 11 | iaciara
# Processing Record 1 of Set 12 | demidov
# Processing Record 2 of Set 12 | norrtalje
# Processing Record 3 of Set 12 | sarangani
# Processing Record 4 of Set 12 | dajal
# Processing Record 5 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 6 of Set 12 | reitz
# Processing Record 7 of Set 12 | zhuhai
# Processing Record 8 of Set 12 | palu
# Processing Record 9 of Set 12 | usinsk
# Processing Record 10 of Set 12 | saint-paul
# Processing Record 11 of Set 12 | kampong cham
# Processing Record 12 of Set 12 | hami
# Processing Record 13 of Set 12 | bom jesus da lapa
# Processing Record 14 of Set 12 | havre-saint-pierre
# Processing Record 15 of Set 12 | mulege
# Processing Record 16 of Set 12 | clyde river
# Processing Record 17 of Set 12 | halkirk
# Processing Record 18 of Set 12 | jiuquan
# Processing Record 19 of Set 12 | shahr-e babak
# Processing Record 20 of Set 12 | panacan
# Processing Record 21 of Set 12 | shakawe
# Processing Record 22 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 12 | jiazi
# Processing Record 24 of Set 12 | pilot butte
# Processing Record 25 of Set 12 | shimoda
# Processing Record 26 of Set 12 | benjamin constant
# Processing Record 27 of Set 12 | barroquinha
# Processing Record 28 of Set 12 | labuhan
# Processing Record 29 of Set 12 | bowen
# Processing Record 30 of Set 12 | hopkins
# Processing Record 31 of Set 12 | berdigestyakh
# Processing Record 32 of Set 12 | bolshoye ignatovo
# City not found. Skipping...
# Processing Record 33 of Set 12 | raton
# Processing Record 34 of Set 12 | coahuayana
# Processing Record 35 of Set 12 | geraldton
# Processing Record 36 of Set 12 | cheremukhovo
# Processing Record 37 of Set 12 | opuwo
# Processing Record 38 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 39 of Set 12 | kovrov
# Processing Record 40 of Set 12 | presidencia roque saenz pena
# Processing Record 41 of Set 12 | teguldet
# Processing Record 42 of Set 12 | papagaios
# Processing Record 43 of Set 12 | synya
# Processing Record 44 of Set 12 | lapeer
# Processing Record 45 of Set 12 | mahina
# Processing Record 46 of Set 12 | pareora
# Processing Record 47 of Set 12 | carballo
# Processing Record 48 of Set 12 | pindiga
# Processing Record 49 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 50 of Set 12 | souillac
# Processing Record 1 of Set 13 | chirongui
# Processing Record 2 of Set 13 | caravelas
# Processing Record 3 of Set 13 | botou
# Processing Record 4 of Set 13 | myski
# Processing Record 5 of Set 13 | nedjo
# Processing Record 6 of Set 13 | nikki
# Processing Record 7 of Set 13 | huesca
# Processing Record 8 of Set 13 | chapleau
# Processing Record 9 of Set 13 | wangqing
# Processing Record 10 of Set 13 | rognan
# Processing Record 11 of Set 13 | son la
# Processing Record 12 of Set 13 | vertientes
# Processing Record 13 of Set 13 | tabas
# Processing Record 14 of Set 13 | tura
# Processing Record 15 of Set 13 | lufilufi
# Processing Record 16 of Set 13 | rudbar
# Processing Record 17 of Set 13 | salinopolis
# Processing Record 18 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 19 of Set 13 | oranjemund
# Processing Record 20 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 22 of Set 13 | gayny
# Processing Record 23 of Set 13 | maniitsoq
# Processing Record 24 of Set 13 | orocue
# Processing Record 25 of Set 13 | kohlu
# Processing Record 26 of Set 13 | algiers
# Processing Record 27 of Set 13 | najran
# Processing Record 28 of Set 13 | adrar
# Processing Record 29 of Set 13 | sinegorye
# Processing Record 30 of Set 13 | gumusyaka
# City not found. Skipping...
# Processing Record 31 of Set 13 | nahuizalco
# Processing Record 32 of Set 13 | burns lake
# Processing Record 33 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 13 | sur
# Processing Record 35 of Set 13 | nalut
# Processing Record 36 of Set 13 | dingle
# Processing Record 37 of Set 13 | palmer
# Processing Record 38 of Set 13 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 39 of Set 13 | aransas pass
# Processing Record 40 of Set 13 | nagar karnul
# Processing Record 41 of Set 13 | tacna
# Processing Record 42 of Set 13 | portland
# Processing Record 43 of Set 13 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 44 of Set 13 | chadiza
# Processing Record 45 of Set 13 | kavaratti
# Processing Record 46 of Set 13 | ituango
# Processing Record 47 of Set 13 | bolshaya murta
# City not found. Skipping...
# Processing Record 48 of Set 13 | wanlaweyn
# Processing Record 49 of Set 13 | san vicente
# Processing Record 50 of Set 13 | odweyne
# Processing Record 1 of Set 14 | traralgon
# Processing Record 2 of Set 14 | genhe
# Processing Record 3 of Set 14 | ostersund
# Processing Record 4 of Set 14 | brae
# Processing Record 5 of Set 14 | almeirim
# Processing Record 6 of Set 14 | awjilah
# Processing Record 7 of Set 14 | kristinehamn
# Processing Record 8 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 9 of Set 14 | aleksandrovsk-sakhalinskiy
# Processing Record 10 of Set 14 | jizan
# Processing Record 11 of Set 14 | hofn
# Processing Record 12 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 14 | tartagal
# Processing Record 14 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 14 | requena
# Processing Record 16 of Set 14 | iralaya
# Processing Record 17 of Set 14 | casper
# Processing Record 18 of Set 14 | dovbysh
# Processing Record 19 of Set 14 | reconquista
# Processing Record 20 of Set 14 | vao
# Processing Record 21 of Set 14 | andenes
# Processing Record 22 of Set 14 | karup
# Processing Record 23 of Set 14 | kedrovyy
# Processing Record 24 of Set 14 | port macquarie
# Processing Record 25 of Set 14 | namibe
# Processing Record 26 of Set 14 | hastings
# Processing Record 27 of Set 14 | broome
# Processing Record 28 of Set 14 | pringsewu
# Processing Record 29 of Set 14 | sarkand
# Processing Record 30 of Set 14 | along
# Processing Record 31 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 14 | oistins
# Processing Record 33 of Set 14 | cascais
# Processing Record 34 of Set 14 | iranshahr
# Processing Record 35 of Set 14 | orlik
# Processing Record 36 of Set 14 | sokoni
# Processing Record 37 of Set 14 | bure
# Processing Record 38 of Set 14 | willowmore
# Processing Record 39 of Set 14 | pueblo nuevo
# Processing Record 40 of Set 14 | rizal
# Processing Record 41 of Set 14 | coetupo
# City not found. Skipping...
# Processing Record 42 of Set 14 | bang saphan
# Processing Record 43 of Set 14 | terralba
# Processing Record 44 of Set 14 | arman
# Processing Record 45 of Set 14 | khasan
# Processing Record 46 of Set 14 | leglise
# Processing Record 47 of Set 14 | verkhnyaya inta
# Processing Record 48 of Set 14 | pitea
# Processing Record 49 of Set 14 | qingyuan
# Processing Record 50 of Set 14 | gondanglegi
# Processing Record 1 of Set 15 | semirom
# Processing Record 2 of Set 15 | kirksville
# Processing Record 3 of Set 15 | rio gallegos
# Processing Record 4 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 5 of Set 15 | bonavista
# Processing Record 6 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 7 of Set 15 | tiarei
# Processing Record 8 of Set 15 | san pedro de ycuamandiyu
# Processing Record 9 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 10 of Set 15 | waltershausen
# Processing Record 11 of Set 15 | xinqing
# Processing Record 12 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 13 of Set 15 | camabatela
# Processing Record 14 of Set 15 | okhotsk
# Processing Record 15 of Set 15 | havre
# Processing Record 16 of Set 15 | ilhabela
# Processing Record 17 of Set 15 | antalaha
# Processing Record 18 of Set 15 | gao
# Processing Record 19 of Set 15 | boden
# Processing Record 20 of Set 15 | kronshagen
# Processing Record 21 of Set 15 | zlobin
# Processing Record 22 of Set 15 | roma
# Processing Record 23 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 15 | san patricio
# Processing Record 25 of Set 15 | clarence town
# Processing Record 26 of Set 15 | kieta
# Processing Record 27 of Set 15 | madimba
# Processing Record 28 of Set 15 | suna
# Processing Record 29 of Set 15 | ternate
# Processing Record 30 of Set 15 | nova olinda do norte
# Processing Record 31 of Set 15 | preobrazheniye
# Processing Record 32 of Set 15 | mabaruma
# Processing Record 33 of Set 15 | liku
# -----------------------------
# Data Retrieval Complete

# %%
len(city_data)
# Out:
# 666

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas -53.1500  -70.9167     55.51        41          20
# 1     Blackwater -23.5833  148.8833     76.57        72          67
# 2       Khatanga  71.9667  102.5000    -22.94       100          99
# 3       Lapithos  35.3375   33.1792     58.23        67           0
# 4  Mar Del Plata -38.0023  -57.5575     63.88        77          11
# 5         Albany  42.6001  -73.9662     37.81        62          97
# 6     Georgetown   5.4112  100.3354     77.90        77          20
# 7  Leningradskiy  69.3833  178.4167     -3.14        98         100
# 8    Meadow Lake  34.8014 -106.5436     65.17        25           0
# 9      Cape Town -33.9258   18.4232     62.10        89          92
#
#    Wind Speed Country Current Description
# 0       20.71      CL          few clouds
# 1       12.48      AU       broken clouds
# 2        6.76      RU     overcast clouds
# 3        5.14      CY           clear sky
# 4       15.01      AR          few clouds
# 5        4.52      US     overcast clouds
# 6       10.36      MY          light rain
# 7       14.81      RU                snow
# 8       10.56      US           clear sky
# 9        1.99      ZA     overcast clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Punta Arenas      CL -53.1500  -70.9167     55.51        41
# 1              Blackwater      AU -23.5833  148.8833     76.57        72
# 2                Khatanga      RU  71.9667  102.5000    -22.94       100
# 3                Lapithos      CY  35.3375   33.1792     58.23        67
# 4           Mar Del Plata      AR -38.0023  -57.5575     63.88        77
# ..                    ...     ...      ...       ...       ...       ...
# 661               Ternate      ID   0.8000  127.4000     82.24        79
# 662  Nova Olinda Do Norte      BR  -3.8881  -59.0942     77.04        92
# 663        Preobrazheniye      RU  42.9019  133.9064     39.72        95
# 664              Mabaruma      GY   8.2000  -59.7833     73.85        95
# 665                  Liku      ID  -0.7275  119.8922     77.67        81
#
#      Cloudiness  Wind Speed Current Description
# 0            20       20.71          few clouds
# 1            67       12.48       broken clouds
# 2            99        6.76     overcast clouds
# 3             0        5.14           clear sky
# 4            11       15.01          few clouds
# ..          ...         ...                 ...
# 661          94        9.73     overcast clouds
# 662          42        1.59    scattered clouds
# 663          91        6.33     overcast clouds
# 664          86        3.42     overcast clouds
# 665          85        1.12          light rain
#
# [666 rows x 9 columns]

# %%
output = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output)
